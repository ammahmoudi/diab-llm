# %% [markdown]
# # Experiment Efficiency Analysis
#
# This notebook analyzes the efficiency metrics from existing experiment runs in the `experiments/` folder. Each experiment contains both accuracy results and comprehensive efficiency reports generated during model training and inference.
#
# ## Experiment Overview
# - **Chronos Experiments**: Trained inference on OhioT1DM dataset (denoised and noisy)
# - **TimeLLM Experiments**: Training and inference on OhioT1DM dataset (denoised and noisy)
# - **Models**: Chronos-T5-Base, TimeLLM variants
# - **Seeds**: Multiple seeds per experiment for statistical robustness
# - **Patients**: 12 different patients for cross-patient validation

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os
from pathlib import Path
import warnings
from scipy import stats
import glob

# Configure display and plotting
warnings.filterwarnings('ignore')
plt.style.use('default')
sns.set_palette("husl")
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 4)

print("Libraries imported successfully!")
print(f"Working directory: {os.getcwd()}")
# Out:
# Libraries imported successfully!
# Working directory: /home/amma/LLM-TIME/notebooks

# %% [markdown]
# ## 2. Discover and Load All Experiment Data

# %%
# Define experiments directory
experiments_dir = Path("/home/amma/LLM-TIME/experiments")
print(f"Scanning experiments directory: {experiments_dir}")
print("=" * 60)

# Find all experiment folders
experiment_folders = []
for item in experiments_dir.iterdir():
    if item.is_dir() and not item.name.endswith('.zip'):
        experiment_folders.append(item)
        print(f"📁 Found experiment: {item.name}")

print(f"\n📊 Total experiment folders found: {len(experiment_folders)}")

# Initialize data storage
experiment_summary = []
all_accuracy_data = []
all_efficiency_data = []

print("\n🔍 Analyzing experiment structure...")
# Out:
# Scanning experiments directory: /home/amma/LLM-TIME/experiments
# ============================================================
# 📁 Found experiment: chronos_trained_inference_ohiot1dm_noisy
# 📁 Found experiment: time_llm_training_inference_ohiot1dm_train_standardized_test_denoised
# 📁 Found experiment: chronos_trained_inference_ohiot1dm_denoised
# 📁 Found experiment: time_llm_training_inference_ohiot1dm_train_standardized_test_noisy
#
# 📊 Total experiment folders found: 4
#
# 🔍 Analyzing experiment structure...

# %% [markdown]
# ## 3. Load Accuracy Results from All Experiments

# %%
def load_experiment_accuracy_data(experiment_path):
    """Load accuracy data from an experiment folder."""
    experiment_name = experiment_path.name
    
    # Look for experiment_results.csv in nested structure
    nested_path = experiment_path / experiment_name
    results_file = nested_path / "experiment_results.csv"
    
    if results_file.exists():
        df = pd.read_csv(results_file)
        df['experiment_name'] = experiment_name
        return df
    else:
        print(f"⚠️  No experiment_results.csv found in {experiment_name}")
        return None

# Load accuracy data from all experiments
print("📈 Loading accuracy results from all experiments...")

for exp_folder in experiment_folders:
    accuracy_data = load_experiment_accuracy_data(exp_folder)
    if accuracy_data is not None:
        all_accuracy_data.append(accuracy_data)
        print(f"  ✅ {exp_folder.name}: {len(accuracy_data)} records")
    else:
        print(f"  ❌ {exp_folder.name}: No data found")

# Combine all accuracy data
if all_accuracy_data:
    combined_accuracy_df = pd.concat(all_accuracy_data, ignore_index=True)
    print(f"\n📊 Combined accuracy dataset: {len(combined_accuracy_df)} total records")
    print(f"   Experiments: {combined_accuracy_df['experiment_name'].nunique()}")
    print(f"   Models: {combined_accuracy_df['model'].nunique()}")
    print(f"   Patients: {combined_accuracy_df['patient_id'].nunique()}")
    print(f"   Seeds: {combined_accuracy_df['seed'].nunique()}")
else:
    print("❌ No accuracy data found in any experiment!")
    combined_accuracy_df = pd.DataFrame()
# Out:
# 📈 Loading accuracy results from all experiments...
#   ✅ chronos_trained_inference_ohiot1dm_noisy: 125 records
# ⚠️  No experiment_results.csv found in time_llm_training_inference_ohiot1dm_train_standardized_test_denoised
#   ❌ time_llm_training_inference_ohiot1dm_train_standardized_test_denoised: No data found
#   ✅ chronos_trained_inference_ohiot1dm_denoised: 60 records
# ⚠️  No experiment_results.csv found in time_llm_training_inference_ohiot1dm_train_standardized_test_noisy
#   ❌ time_llm_training_inference_ohiot1dm_train_standardized_test_noisy: No data found
#
# 📊 Combined accuracy dataset: 185 total records
#    Experiments: 2
#    Models: 1
#    Patients: 12
#    Seeds: 5

# %% [markdown]
# ## 4. Load Efficiency Reports from All Experiments

# %%
def find_efficiency_reports(experiment_path):
    """Find all efficiency reports in an experiment folder."""
    experiment_name = experiment_path.name
    reports = []
    
    # Look for efficiency reports in nested structure
    nested_path = experiment_path / experiment_name
    
    if not nested_path.exists():
        return reports
    
    # Search for JSON files with efficiency/performance keywords
    for json_file in nested_path.rglob("*.json"):
        if any(keyword in json_file.name.lower() for keyword in 
               ['efficiency_report', 'performance_report', 'comprehensive_performance']):
            try:
                with open(json_file, 'r') as f:
                    report_data = json.load(f)
                    report_data['file_path'] = str(json_file)
                    report_data['experiment_name'] = experiment_name
                    report_data['report_type'] = json_file.name
                    
                    # Extract patient ID from path
                    path_parts = json_file.parts
                    patient_part = [p for p in path_parts if p.startswith('patient_')]
                    if patient_part:
                        report_data['patient_id'] = int(patient_part[0].replace('patient_', ''))
                    
                    # Extract seed from path
                    seed_part = [p for p in path_parts if p.startswith('seed_')]
                    if seed_part:
                        seed_str = seed_part[0].split('_')[1]
                        report_data['seed'] = int(seed_str)
                    
                    reports.append(report_data)
            except Exception as e:
                print(f"⚠️  Error loading {json_file}: {e}")
    
    return reports

# Load efficiency data from all experiments
print("⚡ Loading efficiency reports from all experiments...")

for exp_folder in experiment_folders:
    efficiency_reports = find_efficiency_reports(exp_folder)
    if efficiency_reports:
        all_efficiency_data.extend(efficiency_reports)
        print(f"  ✅ {exp_folder.name}: {len(efficiency_reports)} efficiency reports")
    else:
        print(f"  ❌ {exp_folder.name}: No efficiency reports found")

print(f"\n⚡ Total efficiency reports found: {len(all_efficiency_data)}")

# Categorize efficiency reports
efficiency_by_type = {}
for report in all_efficiency_data:
    report_type = report['report_type']
    if report_type not in efficiency_by_type:
        efficiency_by_type[report_type] = []
    efficiency_by_type[report_type].append(report)

print("\n📊 Efficiency reports by type:")
for report_type, reports in efficiency_by_type.items():
    print(f"  • {report_type}: {len(reports)} reports")
# Out:
# ⚡ Loading efficiency reports from all experiments...
#   ✅ chronos_trained_inference_ohiot1dm_noisy: 614 efficiency reports
#   ✅ time_llm_training_inference_ohiot1dm_train_standardized_test_denoised: 342 efficiency reports
#   ✅ chronos_trained_inference_ohiot1dm_denoised: 240 efficiency reports
#   ✅ time_llm_training_inference_ohiot1dm_train_standardized_test_noisy: 300 efficiency reports
#
# ⚡ Total efficiency reports found: 1496
#
# 📊 Efficiency reports by type:
#   • efficiency_report_chronos_2025-10-12_19-34-26.json: 1 reports
#   • efficiency_report_chronos_latest.json: 242 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-34-38.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-34-38.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-53-12.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-53-00.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-53-12.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-12-00.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-12-34.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-36-11.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-36-11.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-35-58.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-54-33.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-54-45.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-54-45.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-11-39.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-33-31.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-33-43.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-33-43.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-52-16.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-52-16.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-52-05.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-35-34.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-35-34.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-35-22.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-12-20.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-53-55.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-54-07.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-54-07.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-34-45.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-34-57.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-34-57.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-12-07.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-53-18.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-53-31.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-53-31.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-12-41.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-36-29.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-36-17.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-36-29.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-54-51.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-55-04.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-55-04.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-54-14.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-54-26.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-54-26.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-35-52.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-35-52.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-35-40.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-12-27.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-11-32.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-33-25.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-33-13.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-33-25.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-51-59.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-51-59.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-51-47.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-11-53.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-34-08.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-34-19.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-34-19.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-52-53.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-52-41.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-52-53.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-34-01.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-33-49.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-34-01.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-52-35.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-52-35.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-52-23.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-11-46.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-29-05.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-11-14.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-11-26.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-11-26.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-51-40.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-51-40.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-51-28.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-32-53.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-33-06.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-33-06.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-41-50.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-35-15.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-35-15.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-35-03.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-12-13.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-53-49.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-53-49.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-53-37.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-38-19.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-38-19.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-38-08.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-13-33.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-56-54.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-56-43.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-56-54.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-39-54.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-39-42.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-39-54.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-58-30.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-58-18.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-58-30.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-14-08.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-55-59.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-55-48.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-55-59.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-13-13.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-37-24.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-37-24.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-37-13.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-39-16.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-39-16.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-39-04.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-13-54.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-57-51.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-57-39.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-57-51.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-38-37.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-38-26.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-38-37.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-13-40.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-57-14.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-57-14.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-57-01.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-58-49.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-58-37.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-58-49.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-40-01.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-40-12.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-40-12.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-14-18.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-58-11.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-57-58.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-58-11.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-39-35.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-39-35.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-39-23.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-14-01.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-55-41.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-55-41.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-55-30.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-37-07.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-36-55.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-37-07.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-13-06.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-13-26.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-38-01.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-38-01.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-37-49.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-56-25.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-56-37.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-56-37.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-56-18.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-56-18.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-56-06.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-37-31.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-37-43.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-37-43.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-13-20.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-36-48.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-36-48.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-36-36.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-55-23.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-55-10.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-55-23.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-13-00.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-13-00.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-12-47.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-38-44.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-38-58.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-38-58.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-13-47.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-57-20.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-57-33.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-57-33.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-49-25.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-49-25.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-49-13.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-18-22.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-08-01.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-08-01.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-07-50.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-09-32.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-09-21.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-09-32.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-50-58.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-50-46.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-50-58.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-18-56.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-48-19.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-48-30.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-48-30.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-18-02.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-07-07.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-07-07.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-06-55.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-50-09.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-50-21.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-50-21.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-18-43.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-08-56.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-08-44.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-08-56.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-08-20.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-08-07.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-08-20.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-18-29.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-49-31.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-49-44.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-49-44.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-51-04.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-51-17.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-51-17.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-09-39.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-09-51.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-09-51.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-19-03.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-18-50.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-50-28.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-50-39.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-50-39.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-09-02.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-09-14.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-09-14.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-06-49.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-06-37.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-06-49.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-17-55.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-48-13.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-48-13.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-48-01.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-18-15.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-49-06.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-49-06.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-48-54.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-07-43.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-07-32.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-07-43.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-07-25.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-07-25.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-07-14.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-18-08.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-48-36.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-48-48.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-48-48.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-17-36.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-17-48.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-17-48.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-47-42.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-47-54.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-47-54.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-06-18.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-06-30.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-06-30.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-50-03.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-49-51.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-50-03.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-08-38.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-08-38.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-08-26.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-18-36.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-16-48.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-04-21.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-04-21.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-04-09.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-45-46.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-45-34.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-45-46.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-17-22.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-47-17.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-47-05.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-47-17.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-05-52.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-05-52.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-05-40.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-03-26.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-03-14.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-03-26.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-44-39.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-44-51.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-44-51.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-16-26.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-17-08.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-05-16.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-05-16.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-05-04.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-46-41.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-46-41.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-46-29.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-16-55.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-04-39.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-04-39.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-04-27.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-46-04.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-45-52.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-46-04.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-06-11.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-05-59.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-06-11.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-17-29.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-47-36.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-47-23.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-47-36.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-05-34.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-05-34.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-05-22.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-46-47.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-46-59.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-46-59.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-17-15.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-03-07.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-03-07.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-02-56.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-44-31.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-44-31.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-44-19.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-16-19.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-45-28.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-45-28.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-45-16.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-16-41.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-04-03.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-03-51.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-04-03.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-16-34.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-45-10.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-45-10.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-44-58.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-03-33.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-03-44.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-03-44.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-02-37.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-02-49.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-02-49.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-44-13.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-44-01.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-44-13.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-16-01.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-16-13.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-16-13.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-46-11.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-46-23.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-46-23.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-04-57.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-04-57.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-04-46.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-17-01.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-15-13.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-00-40.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-00-40.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-00-29.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-42-03.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-41-51.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-42-03.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-15-47.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-02-12.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-02-12.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-02-00.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-43-36.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-43-24.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-43-36.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-59-45.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-59-33.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-59-45.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-41-08.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-40-56.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-41-08.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-14-52.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-01-35.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-01-23.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-01-35.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-15-33.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-42-59.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-42-47.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-42-59.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-00-59.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-00-59.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-00-47.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-42-21.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-42-09.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-42-21.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-15-20.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-02-18.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-02-30.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-02-30.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-43-42.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-43-54.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-43-54.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-15-54.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-15-40.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-43-05.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-43-17.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-43-17.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-01-41.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-01-53.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-01-53.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-40-50.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-40-38.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-40-50.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-59-14.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-59-26.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-59-26.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-14-45.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-15-06.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-41-45.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-41-33.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-41-45.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-00-21.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-00-10.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-00-21.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-00-03.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-59-51.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-00-03.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-41-27.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-41-15.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-41-27.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-14-59.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-40-31.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-40-19.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-40-31.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-59-08.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-59-08.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-58-55.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-14-38.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-14-25.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-14-38.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_19-42-41.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-42-27.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_19-42-41.json: 1 reports
#   • real_performance_report_chronos_2025-10-12_20-01-17.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_20-01-05.json: 1 reports
#   • comprehensive_performance_report_chronos_comprehensive_2025-10-12_20-01-17.json: 1 reports
#   • efficiency_report_chronos_2025-10-12_19-15-27.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_14-14-14.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_14-14-29.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_14-08-01.json: 1 reports
#   • efficiency_report_time_llm_latest.json: 135 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_14-14-29.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_14-50-33.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_14-50-17.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_14-50-33.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_14-44-02.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_13-53-42.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_13-53-28.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_13-53-42.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_13-48-11.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_14-36-06.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_14-28-48.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_14-35-50.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_14-36-06.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_14-14-41.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_14-21-14.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_14-21-14.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_14-20-58.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_14-57-16.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_14-57-00.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_14-57-16.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_14-50-46.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_14-43-33.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_14-43-49.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_14-43-49.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_14-36-19.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_13-47-58.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_13-41-35.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_13-47-58.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_13-47-41.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_14-07-48.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_14-00-37.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_14-07-33.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_14-07-48.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_13-53-55.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_14-00-24.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_14-00-09.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_14-00-24.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_13-41-22.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_13-41-05.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_13-41-22.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_13-34-13.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_14-28-35.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_14-28-16.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_14-28-35.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_14-21-27.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_12-49-14.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_12-49-29.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_12-43-00.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_12-49-29.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_13-25-36.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_13-19-02.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_13-25-16.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_13-25-36.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_12-23-08.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_12-28-39.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_12-28-39.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_12-28-23.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_13-11-02.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_13-03-47.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_13-11-02.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_13-10-46.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_12-55-59.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_12-56-16.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_12-56-16.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_12-49-42.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_13-32-25.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_13-32-25.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_13-25-49.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_13-32-08.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_13-18-49.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_13-18-49.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_13-11-15.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_13-18-32.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_12-22-40.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_12-16-31.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_12-22-56.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_12-22-56.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_12-42-47.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_12-42-47.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_12-42-31.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_12-35-32.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_12-35-04.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_12-28-52.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_12-35-19.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_12-35-19.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_12-16-18.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_12-16-18.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_12-16-01.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_12-09-05.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_13-03-19.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_12-56-28.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_13-03-34.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_13-03-34.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_15-32-35.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_20-38-31.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_20-38-16.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_20-38-31.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_20-32-02.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_21-14-44.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_21-15-00.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_21-15-00.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_21-08-29.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_16-07-13.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_15-18-31.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_15-13-02.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_15-18-16.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_15-18-31.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_20-17-39.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_20-17-23.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_20-12-08.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_20-17-39.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_21-00-17.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_21-00-01.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_20-52-53.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_21-00-17.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_15-52-32.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_15-39-02.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_20-45-07.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_20-45-22.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_20-45-22.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_20-38-44.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_16-13-38.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_21-21-46.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_21-21-46.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_21-15-13.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_21-21-30.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_21-08-16.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_21-08-00.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_21-08-16.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_21-00-30.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_15-59-45.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_15-12-49.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_15-06-26.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_15-12-33.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_15-12-49.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_20-05-33.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_20-11-55.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_20-11-40.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_20-11-55.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_15-25-26.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_20-31-34.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_20-31-49.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_20-31-49.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_20-24-37.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_15-25-13.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_15-24-57.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_15-25-13.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_15-18-43.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_20-24-07.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_20-24-24.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_20-17-52.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_20-24-24.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_14-59-04.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_15-06-13.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_15-06-13.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_15-05-56.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_19-55-46.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_19-58-13.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_20-05-20.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_20-05-20.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_20-05-03.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_15-45-30.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_20-52-25.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_20-45-35.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_20-52-40.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-13_20-52-40.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-13_11-24-12.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-13_11-24-27.json: 1 reports
#   • efficiency_report_time_llm_2025-10-13_11-17-59.json: 1 reports
# ...
#   • real_performance_report_time_llm_training_inference_2025-10-14_08-59-15.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_08-52-58.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_08-59-31.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_08-02-25.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_08-02-10.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_08-02-25.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_07-56-55.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_08-37-44.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_08-44-43.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_08-44-59.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_08-44-59.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_08-30-13.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_08-30-13.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_08-29-57.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_08-23-38.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_08-59-44.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_09-06-01.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_09-06-17.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_09-06-17.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_08-52-45.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_08-52-28.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_08-52-45.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_08-45-12.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_07-50-19.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_07-56-27.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_07-56-43.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_07-56-43.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_08-09-25.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_08-16-40.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_08-16-25.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_08-16-40.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_08-09-12.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_08-02-37.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_08-09-12.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_08-08-56.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_07-50-07.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_07-50-07.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_07-49-50.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_07-43-00.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_08-30-26.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_08-37-32.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_08-37-32.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_08-37-16.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_11-10-35.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_11-04-02.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_11-10-20.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_11-10-35.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_11-40-08.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_11-46-37.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_11-46-37.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_11-46-21.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_10-49-33.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_10-44-04.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_10-49-19.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_10-49-33.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_11-32-10.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_11-24-53.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_11-32-10.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_11-31-54.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_11-17-24.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_11-10-48.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_11-17-08.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_11-17-24.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_11-53-22.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_11-46-50.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_11-53-06.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_11-53-22.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_11-39-55.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_11-39-39.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_11-32-22.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_11-39-55.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_10-43-51.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_10-43-36.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_10-43-51.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_10-37-30.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_10-56-30.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_11-03-49.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_11-03-49.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_11-03-34.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_10-56-17.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_10-56-00.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_10-56-17.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_10-49-47.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_10-30-08.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_10-37-17.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_10-37-17.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_10-37-01.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_11-24-25.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_11-24-41.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_11-24-41.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_11-17-37.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_06-59-36.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_06-59-21.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_06-59-36.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_06-53-06.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_07-36-02.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_07-35-46.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_07-36-02.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_07-29-25.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_06-38-34.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_06-38-34.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_06-33-00.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_06-38-18.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_07-14-00.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_07-21-05.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_07-21-21.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_07-21-21.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_06-59-50.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_07-06-25.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_07-06-09.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_07-06-25.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_07-36-15.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_07-42-47.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_07-42-31.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_07-42-47.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_07-21-34.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_07-29-12.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_07-28-55.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_07-29-12.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_06-32-30.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_06-32-46.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_06-32-46.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_06-26-23.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_06-45-34.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_06-52-37.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_06-52-53.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_06-52-53.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_06-45-21.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_06-45-04.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_06-38-48.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_06-45-21.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_06-18-55.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_06-25-53.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_06-26-10.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_06-26-10.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_07-13-44.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_07-06-38.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_07-13-27.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_07-13-44.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_12-34-02.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_12-33-46.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_12-34-02.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_12-27-32.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_13-10-17.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_13-10-17.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_13-03-41.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_13-09-59.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_12-12-51.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_12-13-06.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_12-07-35.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_12-13-06.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_12-55-25.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_12-48-26.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_12-55-41.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_12-55-41.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_12-40-35.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_12-40-53.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_12-40-53.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_12-34-15.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_13-10-32.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_13-17-05.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_13-16-49.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_13-17-05.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_12-55-54.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_13-03-29.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_13-03-12.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_13-03-29.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_12-07-23.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_12-00-59.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_12-07-23.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_12-07-07.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_12-27-19.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_12-27-03.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_12-27-19.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_12-20-02.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_12-13-19.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_12-19-49.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_12-19-49.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_12-19-33.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_12-00-47.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_11-53-35.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_12-00-47.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_12-00-30.json: 1 reports
#   • real_performance_report_time_llm_training_inference_2025-10-14_12-47-56.json: 1 reports
#   • real_performance_report_time_llm_training_mode_2025-10-14_12-48-13.json: 1 reports
#   • efficiency_report_time_llm_2025-10-14_12-41-06.json: 1 reports
#   • comprehensive_performance_report_time_llm_comprehensive_2025-10-14_12-48-13.json: 1 reports

# %% [markdown]
# ## 5. Create Comprehensive Accuracy Analysis

# %%
if not combined_accuracy_df.empty:
    print("📈 ACCURACY ANALYSIS ACROSS ALL EXPERIMENTS")
    print("=" * 60)
    
    # Overall statistics
    print("\n📊 Overall Accuracy Statistics:")
    accuracy_stats = combined_accuracy_df[['rmse', 'mae', 'mape']].describe()
    print(accuracy_stats.round(4))
    
    # By experiment analysis
    print("\n🧪 Performance by Experiment:")
    exp_summary = combined_accuracy_df.groupby('experiment_name').agg({
        'rmse': ['mean', 'std', 'count'],
        'mae': ['mean', 'std'],
        'mape': ['mean', 'std'],
        'patient_id': 'nunique',
        'seed': 'nunique'
    }).round(4)
    
    exp_summary.columns = ['_'.join(col).strip() for col in exp_summary.columns]
    print(exp_summary)
    
    # By model analysis
    print("\n🤖 Performance by Model:")
    model_summary = combined_accuracy_df.groupby('model').agg({
        'rmse': ['mean', 'std', 'count'],
        'mae': ['mean', 'std'],
        'mape': ['mean', 'std']
    }).round(4)
    
    model_summary.columns = ['_'.join(col).strip() for col in model_summary.columns]
    print(model_summary)
    
    # Data quality analysis
    print("\n🔍 Data Quality Analysis:")
    if 'denoised' in combined_accuracy_df['experiment_name'].iloc[0]:
        denoised_data = combined_accuracy_df[combined_accuracy_df['experiment_name'].str.contains('denoised')]
        noisy_data = combined_accuracy_df[combined_accuracy_df['experiment_name'].str.contains('noisy')]
        
        if len(denoised_data) > 0 and len(noisy_data) > 0:
            print(f"\nDenoised Data (n={len(denoised_data)}):")
            print(f"  RMSE: {denoised_data['rmse'].mean():.4f} ± {denoised_data['rmse'].std():.4f}")
            print(f"  MAE:  {denoised_data['mae'].mean():.4f} ± {denoised_data['mae'].std():.4f}")
            
            print(f"\nNoisy Data (n={len(noisy_data)}):")
            print(f"  RMSE: {noisy_data['rmse'].mean():.4f} ± {noisy_data['rmse'].std():.4f}")
            print(f"  MAE:  {noisy_data['mae'].mean():.4f} ± {noisy_data['mae'].std():.4f}")
            
            # Statistical test
            t_stat, p_val = stats.ttest_ind(denoised_data['rmse'], noisy_data['rmse'])
            print(f"\nStatistical Test (Denoised vs Noisy RMSE):")
            print(f"  t-statistic: {t_stat:.4f}")
            print(f"  p-value: {p_val:.4f}")
            print(f"  Significant difference: {'Yes' if p_val < 0.05 else 'No'}")
else:
    print("❌ No accuracy data available for analysis")
# Out:
# 📈 ACCURACY ANALYSIS ACROSS ALL EXPERIMENTS
# ============================================================
#
# 📊 Overall Accuracy Statistics:
#            rmse       mae     mape
# count  185.0000  185.0000  60.0000
# mean    61.9211   28.2191   0.0711
# std     31.7637   12.5120   0.0256
# min     12.3725    7.8019   0.0408
# 25%     31.9175   11.1477   0.0572
# 50%     67.7227   34.6390   0.0620
# 75%     74.2857   36.7637   0.0789
# max    179.3407   46.9758   0.1497
#
# 🧪 Performance by Experiment:
#                                              rmse_mean  rmse_std  rmse_count  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised    30.6543   24.3671          60
# chronos_trained_inference_ohiot1dm_noisy       76.9291   22.6831         125
#
#                                              mae_mean  mae_std  mape_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised   11.0618   3.3808     0.0711
# chronos_trained_inference_ohiot1dm_noisy      36.4546   4.0063        NaN
#
#                                              mape_std  patient_id_nunique  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised    0.0256                  12
# chronos_trained_inference_ohiot1dm_noisy          NaN                  12
#
#                                              seed_nunique
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised             5
# chronos_trained_inference_ohiot1dm_noisy                5
#
# 🤖 Performance by Model:
#                         rmse_mean  rmse_std  rmse_count  mae_mean  mae_std  \
# model
# amazon-chronos-t5-base    61.9211   31.7637         185   28.2191   12.512
#
#                         mape_mean  mape_std
# model
# amazon-chronos-t5-base     0.0711    0.0256
#
# 🔍 Data Quality Analysis:
#            rmse       mae     mape
# count  185.0000  185.0000  60.0000
# mean    61.9211   28.2191   0.0711
# std     31.7637   12.5120   0.0256
# min     12.3725    7.8019   0.0408
# 25%     31.9175   11.1477   0.0572
# 50%     67.7227   34.6390   0.0620
# 75%     74.2857   36.7637   0.0789
# max    179.3407   46.9758   0.1497
#
# 🧪 Performance by Experiment:
#                                              rmse_mean  rmse_std  rmse_count  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised    30.6543   24.3671          60
# chronos_trained_inference_ohiot1dm_noisy       76.9291   22.6831         125
#
#                                              mae_mean  mae_std  mape_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised   11.0618   3.3808     0.0711
# chronos_trained_inference_ohiot1dm_noisy      36.4546   4.0063        NaN
#
#                                              mape_std  patient_id_nunique  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised    0.0256                  12
# chronos_trained_inference_ohiot1dm_noisy          NaN                  12
#
#                                              seed_nunique
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised             5
# chronos_trained_inference_ohiot1dm_noisy                5
#
# 🤖 Performance by Model:
#                         rmse_mean  rmse_std  rmse_count  mae_mean  mae_std  \
# model
# amazon-chronos-t5-base    61.9211   31.7637         185   28.2191   12.512
#
#                         mape_mean  mape_std
# model
# amazon-chronos-t5-base     0.0711    0.0256
#
# 🔍 Data Quality Analysis:

# %% [markdown]
# ## 6. Extract and Analyze Efficiency Metrics

# %%
def extract_efficiency_metrics(efficiency_reports):
    """Extract key efficiency metrics from reports."""
    efficiency_data = []
    
    for report in efficiency_reports:
        metrics = {
            'experiment_name': report.get('experiment_name', 'unknown'),
            'patient_id': report.get('patient_id', 0),
            'seed': report.get('seed', 0),
            'model_name': report.get('model_name', 'unknown'),
            'report_type': report.get('report_type', 'unknown'),
            'timestamp': report.get('timestamp', 'unknown')
        }
        
        # Extract model characteristics
        if 'model_characteristics' in report:
            char = report['model_characteristics']
            metrics['total_parameters'] = char.get('total_parameters', 0)
            metrics['model_size_mb'] = char.get('model_size_mb', 0)
            metrics['model_dtype'] = char.get('model_dtype', 'unknown')
        
        # Extract real performance measurements
        if 'real_performance_measurements' in report:
            perf = report['real_performance_measurements']
            
            # Timing metrics
            if 'inference_timing' in perf:
                timing = perf['inference_timing']
                metrics['avg_latency_ms'] = timing.get('average_latency_ms', 0)
                metrics['median_latency_ms'] = timing.get('median_latency_ms', 0)
                metrics['p95_latency_ms'] = timing.get('p95_latency_ms', 0)
                metrics['total_inferences'] = timing.get('total_inferences_measured', 0)
            
            # Memory metrics
            if 'memory_usage' in perf:
                memory = perf['memory_usage']
                metrics['peak_ram_mb'] = memory.get('process_peak_ram_mb', memory.get('peak_ram_mb', 0))
                metrics['avg_ram_mb'] = memory.get('process_average_ram_mb', memory.get('average_ram_mb', 0))
                metrics['system_peak_ram_mb'] = memory.get('system_peak_ram_mb', 0)
            
            # GPU metrics
            if 'gpu_memory_usage' in perf:
                gpu = perf['gpu_memory_usage']
                metrics['peak_gpu_mb'] = gpu.get('peak_allocated_mb', 0)
                metrics['avg_gpu_mb'] = gpu.get('average_allocated_mb', 0)
            
            # NVIDIA ML metrics
            if 'nvidia_ml_metrics' in perf:
                nvidia = perf['nvidia_ml_metrics']
                metrics['peak_gpu_util'] = nvidia.get('peak_gpu_utilization_percent', 0)
                metrics['avg_gpu_util'] = nvidia.get('average_gpu_utilization_percent', 0)
                metrics['peak_temp_c'] = nvidia.get('peak_temperature_celsius', 0)
                metrics['peak_power_w'] = nvidia.get('peak_power_usage_watts', 0)
                metrics['avg_power_w'] = nvidia.get('average_power_usage_watts', 0)
        
        # Edge deployment analysis
        if 'edge_deployment_analysis' in report:
            edge = report['edge_deployment_analysis']
            metrics['edge_feasibility'] = edge.get('feasibility_assessment', 'unknown')
            metrics['feasible_devices'] = len(edge.get('feasible_edge_devices', []))
        
        efficiency_data.append(metrics)
    
    return pd.DataFrame(efficiency_data)

# Extract efficiency metrics
if all_efficiency_data:
    print("⚡ EFFICIENCY ANALYSIS ACROSS ALL EXPERIMENTS")
    print("=" * 60)
    
    efficiency_df = extract_efficiency_metrics(all_efficiency_data)
    print(f"\n📊 Efficiency dataset: {len(efficiency_df)} records")
    print(f"   Experiments: {efficiency_df['experiment_name'].nunique()}")
    print(f"   Patients: {efficiency_df['patient_id'].nunique()}")
    print(f"   Seeds: {efficiency_df['seed'].nunique()}")
    print(f"   Report types: {efficiency_df['report_type'].nunique()}")
    
    # Filter for real performance reports (most comprehensive)
    real_perf_df = efficiency_df[efficiency_df['report_type'].str.contains('real_performance', na=False)]
    
    if not real_perf_df.empty:
        print(f"\n⚡ Real performance data: {len(real_perf_df)} records")
        
        # Overall efficiency statistics
        print("\n📈 Overall Efficiency Statistics:")
        efficiency_metrics = ['avg_latency_ms', 'peak_ram_mb', 'peak_gpu_mb', 'peak_gpu_util', 'peak_power_w']
        available_metrics = [col for col in efficiency_metrics if col in real_perf_df.columns]
        
        if available_metrics:
            eff_stats = real_perf_df[available_metrics].describe()
            print(eff_stats.round(2))
        
        # Efficiency by experiment
        print("\n🧪 Efficiency by Experiment:")
        exp_eff_summary = real_perf_df.groupby('experiment_name')[available_metrics].agg(['mean', 'std']).round(2)
        print(exp_eff_summary)
    else:
        print("❌ No real performance data found")
        real_perf_df = pd.DataFrame()
else:
    print("❌ No efficiency data available for analysis")
    efficiency_df = pd.DataFrame()
    real_perf_df = pd.DataFrame()
# Out:
# ⚡ EFFICIENCY ANALYSIS ACROSS ALL EXPERIMENTS
# ============================================================
#
# 📊 Efficiency dataset: 1496 records
#    Experiments: 4
#    Patients: 12
#    Seeds: 5
#    Report types: 1121
#
# ⚡ Real performance data: 433 records
#
# 📈 Overall Efficiency Statistics:
#        avg_latency_ms  peak_ram_mb  peak_gpu_mb  peak_gpu_util  peak_power_w
# count          433.00       433.00       433.00         433.00        433.00
# mean        120248.50      1992.34      3266.76          51.15        212.31
# std         170521.69       325.54      2526.83          14.51         65.39
# min          10494.45      1584.06       902.63          33.00        125.68
# 25%          11434.49      1624.20      1212.94          36.00        144.06
# 50%          14672.05      2203.22      2007.32          54.00        229.51
# 75%         366206.68      2268.22      6735.40          70.00        291.13
# max         449600.25      2746.79      7516.43          74.00        314.76
#
# 🧪 Efficiency by Experiment:
#                                                    avg_latency_ms             \
#                                                              mean        std
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised              11401.04     383.61
# chronos_trained_inference_ohiot1dm_noisy                 11352.04     434.18
# time_llm_training_inference_ohiot1dm_train_stan...      200827.12  187869.41
# time_llm_training_inference_ohiot1dm_train_stan...      202155.52  188976.51
#
#                                                    peak_ram_mb         \
#                                                           mean    std
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised            1622.03  12.37
# chronos_trained_inference_ohiot1dm_noisy               1622.44  11.97
# time_llm_training_inference_ohiot1dm_train_stan...     2270.47  88.30
# time_llm_training_inference_ohiot1dm_train_stan...     2266.16  67.02
#
#                                                    peak_gpu_mb           \
#                                                           mean      std
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised            1209.96     7.15
# chronos_trained_inference_ohiot1dm_noisy               1208.88     7.71
# time_llm_training_inference_ohiot1dm_train_stan...     4782.41  2358.42
# time_llm_training_inference_ohiot1dm_train_stan...     4822.10  2398.09
#
#                                                    peak_gpu_util        \
#                                                             mean   std
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                35.97  0.86
# chronos_trained_inference_ohiot1dm_noisy                   35.85  0.85
# time_llm_training_inference_ohiot1dm_train_stan...         62.48  8.02
# time_llm_training_inference_ohiot1dm_train_stan...         62.60  7.86
#
#                                                    peak_power_w
#                                                            mean    std
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised              141.95   4.97
# chronos_trained_inference_ohiot1dm_noisy                 143.08   5.84
# time_llm_training_inference_ohiot1dm_train_stan...       264.96  33.57
# time_llm_training_inference_ohiot1dm_train_stan...       263.45  33.48

# %% [markdown]
# ## 7. Efficiency vs Accuracy Analysis

# %%
def merge_accuracy_efficiency_data():
    """Merge accuracy and efficiency data for joint analysis."""
    if combined_accuracy_df.empty or real_perf_df.empty:
        print("❌ Cannot merge: missing accuracy or efficiency data")
        return pd.DataFrame()
    
    # Merge on experiment, patient, and seed
    merged_df = pd.merge(
        combined_accuracy_df,
        real_perf_df,
        on=['experiment_name', 'patient_id', 'seed'],
        how='inner',
        suffixes=('_acc', '_eff')
    )
    
    return merged_df

# Create joint analysis
print("🔄 EFFICIENCY vs ACCURACY ANALYSIS")
print("=" * 50)

merged_data = merge_accuracy_efficiency_data()

if not merged_data.empty:
    print(f"\n✅ Successfully merged {len(merged_data)} records")
    print(f"   Experiments: {merged_data['experiment_name'].nunique()}")
    print(f"   Patients: {merged_data['patient_id'].nunique()}")
    print(f"   Seeds: {merged_data['seed'].nunique()}")
    
    # Calculate efficiency-accuracy ratios
    merged_data['efficiency_score'] = 1 / (merged_data['avg_latency_ms'] / 1000)  # Samples per second
    merged_data['accuracy_score'] = 1 / merged_data['rmse']  # Higher is better
    merged_data['efficiency_accuracy_ratio'] = merged_data['efficiency_score'] / merged_data['accuracy_score']
    
    # Performance trade-offs
    print("\n⚖️  Efficiency-Accuracy Trade-offs:")
    tradeoff_summary = merged_data.groupby('experiment_name').agg({
        'rmse': ['mean', 'std'],
        'avg_latency_ms': ['mean', 'std'],
        'peak_ram_mb': ['mean', 'std'],
        'efficiency_score': ['mean', 'std']
    }).round(3)
    
    tradeoff_summary.columns = ['_'.join(col).strip() for col in tradeoff_summary.columns]
    print(tradeoff_summary)
    
    # Correlation analysis
    print("\n📊 Correlation Analysis:")
    correlation_cols = ['rmse', 'mae', 'avg_latency_ms', 'peak_ram_mb', 'peak_gpu_mb']
    available_corr_cols = [col for col in correlation_cols if col in merged_data.columns]
    
    if len(available_corr_cols) >= 2:
        correlations = merged_data[available_corr_cols].corr()
        print(correlations.round(3))
    
else:
    print("❌ Could not merge accuracy and efficiency data")
    merged_data = pd.DataFrame()
# Out:
# 🔄 EFFICIENCY vs ACCURACY ANALYSIS
# ==================================================
#
# ✅ Successfully merged 325 records
#    Experiments: 2
#    Patients: 12
#    Seeds: 5
#
# ⚖️  Efficiency-Accuracy Trade-offs:
#                                              rmse_mean  rmse_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised     30.654    24.367
# chronos_trained_inference_ohiot1dm_noisy        76.090    22.350
#
#                                              avg_latency_ms_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised            11401.045
# chronos_trained_inference_ohiot1dm_noisy               11379.546
#
#                                              avg_latency_ms_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised             383.611
# chronos_trained_inference_ohiot1dm_noisy                441.402
#
#                                              peak_ram_mb_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised          1622.028
# chronos_trained_inference_ohiot1dm_noisy             1622.544
#
#                                              peak_ram_mb_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised           12.373
# chronos_trained_inference_ohiot1dm_noisy              11.861
#
#                                              efficiency_score_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                  0.088
# chronos_trained_inference_ohiot1dm_noisy                     0.088
#
#                                              efficiency_score_std
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                 0.003
# chronos_trained_inference_ohiot1dm_noisy                    0.003
#
# 📊 Correlation Analysis:
#                  rmse    mae  avg_latency_ms  peak_ram_mb  peak_gpu_mb
# rmse            1.000  0.777           0.083       -0.105       -0.063
# mae             0.777  1.000          -0.062       -0.054       -0.092
# avg_latency_ms  0.083 -0.062           1.000        0.002        0.047
# peak_ram_mb    -0.105 -0.054           0.002        1.000        0.144
# peak_gpu_mb    -0.063 -0.092           0.047        0.144        1.000

# %% [markdown]
# ## 8. Create Comprehensive Visualizations

# %%
# Create comprehensive visualization dashboard
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Experiment Efficiency and Accuracy Analysis', fontsize=16, fontweight='bold')

# 1. Accuracy comparison across experiments
if not combined_accuracy_df.empty:
    ax1 = axes[0, 0]
    exp_names = combined_accuracy_df['experiment_name'].unique()
    rmse_by_exp = [combined_accuracy_df[combined_accuracy_df['experiment_name'] == exp]['rmse'].values for exp in exp_names]
    
    bp1 = ax1.boxplot(rmse_by_exp, labels=[exp.split('_')[-1] for exp in exp_names], patch_artist=True)
    ax1.set_title('RMSE Distribution by Experiment', fontweight='bold')
    ax1.set_ylabel('RMSE')
    ax1.tick_params(axis='x', rotation=45)
    
    # Color boxes
    colors = ['lightblue', 'lightgreen', 'lightcoral', 'gold']
    for patch, color in zip(bp1['boxes'], colors[:len(bp1['boxes'])]):
        patch.set_facecolor(color)

# 2. Efficiency metrics comparison
if not real_perf_df.empty and 'avg_latency_ms' in real_perf_df.columns:
    ax2 = axes[0, 1]
    exp_efficiency = real_perf_df.groupby('experiment_name')['avg_latency_ms'].mean()
    exp_efficiency.plot(kind='bar', ax=ax2, color='skyblue', alpha=0.7)
    ax2.set_title('Average Latency by Experiment', fontweight='bold')
    ax2.set_ylabel('Latency (ms)')
    ax2.tick_params(axis='x', rotation=45)

# 3. Memory usage comparison
if not real_perf_df.empty and 'peak_ram_mb' in real_perf_df.columns:
    ax3 = axes[0, 2]
    exp_memory = real_perf_df.groupby('experiment_name')['peak_ram_mb'].mean()
    exp_memory.plot(kind='bar', ax=ax3, color='lightcoral', alpha=0.7)
    ax3.set_title('Peak RAM Usage by Experiment', fontweight='bold')
    ax3.set_ylabel('RAM (MB)')
    ax3.tick_params(axis='x', rotation=45)

# 4. Efficiency vs Accuracy scatter plot
if not merged_data.empty:
    ax4 = axes[1, 0]
    scatter = ax4.scatter(merged_data['avg_latency_ms'], merged_data['rmse'], 
                         c=merged_data['experiment_name'].astype('category').cat.codes, 
                         alpha=0.6, s=50)
    ax4.set_xlabel('Average Latency (ms)')
    ax4.set_ylabel('RMSE')
    ax4.set_title('Efficiency vs Accuracy Trade-off', fontweight='bold')
    
    # Add trend line
    if len(merged_data) > 1:
        z = np.polyfit(merged_data['avg_latency_ms'], merged_data['rmse'], 1)
        p = np.poly1d(z)
        ax4.plot(merged_data['avg_latency_ms'], p(merged_data['avg_latency_ms']), "r--", alpha=0.8)

# 5. Patient performance variability
if not combined_accuracy_df.empty:
    ax5 = axes[1, 1]
    patient_rmse = combined_accuracy_df.groupby('patient_id')['rmse'].agg(['mean', 'std'])
    ax5.errorbar(range(len(patient_rmse)), patient_rmse['mean'], 
                yerr=patient_rmse['std'], fmt='o-', capsize=5, alpha=0.7)
    ax5.set_title('RMSE by Patient (with std)', fontweight='bold')
    ax5.set_xlabel('Patient Index')
    ax5.set_ylabel('RMSE')
    ax5.grid(True, alpha=0.3)

# 6. Power consumption analysis
if not real_perf_df.empty and 'peak_power_w' in real_perf_df.columns:
    power_data = real_perf_df.dropna(subset=['peak_power_w'])
    if not power_data.empty:
        ax6 = axes[1, 2]
        exp_power = power_data.groupby('experiment_name')['peak_power_w'].mean()
        exp_power.plot(kind='bar', ax=ax6, color='gold', alpha=0.7)
        ax6.set_title('Peak Power Consumption', fontweight='bold')
        ax6.set_ylabel('Power (W)')
        ax6.tick_params(axis='x', rotation=45)
    else:
        axes[1, 2].text(0.5, 0.5, 'No Power Data Available', 
                        transform=axes[1, 2].transAxes, ha='center', va='center')
else:
    axes[1, 2].text(0.5, 0.5, 'No Power Data Available', 
                    transform=axes[1, 2].transAxes, ha='center', va='center')

plt.tight_layout()
plt.savefig('/home/amma/LLM-TIME/notebooks/experiment_analysis_plots.png', dpi=300, bbox_inches='tight')
plt.show()

print("📊 Visualization plots saved to: /home/amma/LLM-TIME/notebooks/experiment_analysis_plots.png")
# Out:
# 📊 Visualization plots saved to: /home/amma/LLM-TIME/notebooks/experiment_analysis_plots.png

# %% [markdown]
# ## 9. Generate Summary Tables for Paper

# %%
def create_paper_summary_tables():
    """Create summary tables suitable for research paper."""
    
    tables = {}
    
    # Table 1: Accuracy Summary by Experiment
    if not combined_accuracy_df.empty:
        accuracy_table = combined_accuracy_df.groupby('experiment_name').agg({
            'rmse': ['mean', 'std', 'count'],
            'mae': ['mean', 'std'],
            'mape': ['mean', 'std'],
            'patient_id': 'nunique',
            'seed': 'nunique'
        }).round(4)
        
        # Flatten column names
        accuracy_table.columns = ['_'.join(col).strip() for col in accuracy_table.columns]
        tables['accuracy_summary'] = accuracy_table
    
    # Table 2: Efficiency Summary by Experiment
    if not real_perf_df.empty:
        efficiency_metrics = ['avg_latency_ms', 'peak_ram_mb', 'peak_gpu_mb', 'peak_gpu_util', 'peak_power_w']
        available_eff_metrics = [col for col in efficiency_metrics if col in real_perf_df.columns]
        
        if available_eff_metrics:
            efficiency_table = real_perf_df.groupby('experiment_name')[available_eff_metrics].agg(['mean', 'std', 'count']).round(2)
            efficiency_table.columns = ['_'.join(col).strip() for col in efficiency_table.columns]
            tables['efficiency_summary'] = efficiency_table
    
    # Table 3: Combined Efficiency-Accuracy Summary
    if not merged_data.empty:
        combined_table = merged_data.groupby('experiment_name').agg({
            'rmse': ['mean', 'std'],
            'mae': ['mean', 'std'],
            'avg_latency_ms': ['mean', 'std'],
            'peak_ram_mb': ['mean', 'std'],
            'peak_gpu_mb': ['mean', 'std'],
            'patient_id': 'nunique'
        }).round(3)
        
        combined_table.columns = ['_'.join(col).strip() for col in combined_table.columns]
        tables['combined_summary'] = combined_table
    
    return tables

# Generate summary tables
print("📋 GENERATING SUMMARY TABLES FOR PAPER")
print("=" * 50)

summary_tables = create_paper_summary_tables()

for table_name, table_df in summary_tables.items():
    print(f"\n📊 {table_name.upper().replace('_', ' ')}:")
    print("=" * 60)
    print(table_df)
    
    # Save to CSV
    csv_path = f"/home/amma/LLM-TIME/notebooks/{table_name}_table.csv"
    table_df.to_csv(csv_path)
    print(f"💾 Saved to: {csv_path}")

# Generate LaTeX table for paper
if 'combined_summary' in summary_tables:
    latex_table = summary_tables['combined_summary'].to_latex(float_format="%.3f")
    latex_path = "/home/amma/LLM-TIME/notebooks/experiment_summary_table.tex"
    with open(latex_path, 'w') as f:
        f.write(latex_table)
    print(f"\n📄 LaTeX table saved to: {latex_path}")
# Out:
# 📋 GENERATING SUMMARY TABLES FOR PAPER
# ==================================================
#
# 📊 ACCURACY SUMMARY:
# ============================================================
#                                              rmse_mean  rmse_std  rmse_count  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised    30.6543   24.3671          60
# chronos_trained_inference_ohiot1dm_noisy       76.9291   22.6831         125
#
#                                              mae_mean  mae_std  mape_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised   11.0618   3.3808     0.0711
# chronos_trained_inference_ohiot1dm_noisy      36.4546   4.0063        NaN
#
#                                              mape_std  patient_id_nunique  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised    0.0256                  12
# chronos_trained_inference_ohiot1dm_noisy          NaN                  12
#
#                                              seed_nunique
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised             5
# chronos_trained_inference_ohiot1dm_noisy                5
# 💾 Saved to: /home/amma/LLM-TIME/notebooks/accuracy_summary_table.csv
#
# 📊 EFFICIENCY SUMMARY:
# ============================================================
#                                                     avg_latency_ms_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                    11401.04
# chronos_trained_inference_ohiot1dm_noisy                       11352.04
# time_llm_training_inference_ohiot1dm_train_stan...            200827.12
# time_llm_training_inference_ohiot1dm_train_stan...            202155.52
#
#                                                     avg_latency_ms_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                     383.61
# chronos_trained_inference_ohiot1dm_noisy                        434.18
# time_llm_training_inference_ohiot1dm_train_stan...           187869.41
# time_llm_training_inference_ohiot1dm_train_stan...           188976.51
#
#                                                     avg_latency_ms_count  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                           60
# chronos_trained_inference_ohiot1dm_noisy                             125
# time_llm_training_inference_ohiot1dm_train_stan...                   128
# time_llm_training_inference_ohiot1dm_train_stan...                   120
#
#                                                     peak_ram_mb_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                  1622.03
# chronos_trained_inference_ohiot1dm_noisy                     1622.44
# time_llm_training_inference_ohiot1dm_train_stan...           2270.47
# time_llm_training_inference_ohiot1dm_train_stan...           2266.16
#
#                                                     peak_ram_mb_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                   12.37
# chronos_trained_inference_ohiot1dm_noisy                      11.97
# time_llm_training_inference_ohiot1dm_train_stan...            88.30
# time_llm_training_inference_ohiot1dm_train_stan...            67.02
#
#                                                     peak_ram_mb_count  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                        60
# chronos_trained_inference_ohiot1dm_noisy                          125
# time_llm_training_inference_ohiot1dm_train_stan...                128
# time_llm_training_inference_ohiot1dm_train_stan...                120
#
#                                                     peak_gpu_mb_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                  1209.96
# chronos_trained_inference_ohiot1dm_noisy                     1208.88
# time_llm_training_inference_ohiot1dm_train_stan...           4782.41
# time_llm_training_inference_ohiot1dm_train_stan...           4822.10
#
#                                                     peak_gpu_mb_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                    7.15
# chronos_trained_inference_ohiot1dm_noisy                       7.71
# time_llm_training_inference_ohiot1dm_train_stan...          2358.42
# time_llm_training_inference_ohiot1dm_train_stan...          2398.09
#
#                                                     peak_gpu_mb_count  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                        60
# chronos_trained_inference_ohiot1dm_noisy                          125
# time_llm_training_inference_ohiot1dm_train_stan...                128
# time_llm_training_inference_ohiot1dm_train_stan...                120
#
#                                                     peak_gpu_util_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                      35.97
# chronos_trained_inference_ohiot1dm_noisy                         35.85
# time_llm_training_inference_ohiot1dm_train_stan...               62.48
# time_llm_training_inference_ohiot1dm_train_stan...               62.60
#
#                                                     peak_gpu_util_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                      0.86
# chronos_trained_inference_ohiot1dm_noisy                         0.85
# time_llm_training_inference_ohiot1dm_train_stan...               8.02
# time_llm_training_inference_ohiot1dm_train_stan...               7.86
#
#                                                     peak_gpu_util_count  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                          60
# chronos_trained_inference_ohiot1dm_noisy                            125
# time_llm_training_inference_ohiot1dm_train_stan...                  128
# time_llm_training_inference_ohiot1dm_train_stan...                  120
#
#                                                     peak_power_w_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                    141.95
# chronos_trained_inference_ohiot1dm_noisy                       143.08
# time_llm_training_inference_ohiot1dm_train_stan...             264.96
# time_llm_training_inference_ohiot1dm_train_stan...             263.45
#
#                                                     peak_power_w_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                     4.97
# chronos_trained_inference_ohiot1dm_noisy                        5.84
# time_llm_training_inference_ohiot1dm_train_stan...             33.57
# time_llm_training_inference_ohiot1dm_train_stan...             33.48
#
#                                                     peak_power_w_count
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                         60
# chronos_trained_inference_ohiot1dm_noisy                           125
# time_llm_training_inference_ohiot1dm_train_stan...                 128
# time_llm_training_inference_ohiot1dm_train_stan...                 120
# 💾 Saved to: /home/amma/LLM-TIME/notebooks/efficiency_summary_table.csv
#
# 📊 COMBINED SUMMARY:
# ============================================================
#                                              rmse_mean  rmse_std  mae_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised     30.654    24.367    11.062
# chronos_trained_inference_ohiot1dm_noisy        76.090    22.350    36.134
#
#                                              mae_std  avg_latency_ms_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised    3.381            11401.045
# chronos_trained_inference_ohiot1dm_noisy       4.258            11379.546
#
#                                              avg_latency_ms_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised             383.611
# chronos_trained_inference_ohiot1dm_noisy                441.402
#
#                                              peak_ram_mb_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised          1622.028
# chronos_trained_inference_ohiot1dm_noisy             1622.544
#
#                                              peak_ram_mb_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised           12.373
# chronos_trained_inference_ohiot1dm_noisy              11.861
#
#                                              peak_gpu_mb_mean  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised          1209.956
# chronos_trained_inference_ohiot1dm_noisy             1209.008
#
#                                              peak_gpu_mb_std  \
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised            7.150
# chronos_trained_inference_ohiot1dm_noisy               7.599
#
#                                              patient_id_nunique
# experiment_name
# chronos_trained_inference_ohiot1dm_denoised                  12
# chronos_trained_inference_ohiot1dm_noisy                     12
# 💾 Saved to: /home/amma/LLM-TIME/notebooks/combined_summary_table.csv
#
# 📄 LaTeX table saved to: /home/amma/LLM-TIME/notebooks/experiment_summary_table.tex

# %% [markdown]
# ## 10. Key Findings and Recommendations

# %%
print("🎯 KEY FINDINGS AND RECOMMENDATIONS")
print("=" * 60)

# Data availability summary
print("\n📊 DATA AVAILABILITY:")
print(f"  ✅ Accuracy data: {len(combined_accuracy_df) if not combined_accuracy_df.empty else 0} records")
print(f"  ⚡ Efficiency data: {len(real_perf_df) if not real_perf_df.empty else 0} records")
print(f"  🔄 Combined data: {len(merged_data) if not merged_data.empty else 0} records")

# Key insights
if not combined_accuracy_df.empty:
    print("\n🔍 ACCURACY INSIGHTS:")
    best_exp = combined_accuracy_df.groupby('experiment_name')['rmse'].mean().idxmin()
    best_rmse = combined_accuracy_df.groupby('experiment_name')['rmse'].mean().min()
    print(f"  🏆 Best performing experiment: {best_exp} (RMSE: {best_rmse:.4f})")
    
    # Data quality comparison
    if 'denoised' in combined_accuracy_df['experiment_name'].iloc[0]:
        denoised_rmse = combined_accuracy_df[combined_accuracy_df['experiment_name'].str.contains('denoised')]['rmse'].mean()
        noisy_rmse = combined_accuracy_df[combined_accuracy_df['experiment_name'].str.contains('noisy')]['rmse'].mean()
        improvement = ((noisy_rmse - denoised_rmse) / noisy_rmse) * 100
        print(f"  📈 Denoising improvement: {improvement:.2f}% RMSE reduction")

if not real_perf_df.empty:
    print("\n⚡ EFFICIENCY INSIGHTS:")
    if 'avg_latency_ms' in real_perf_df.columns:
        fastest_exp = real_perf_df.groupby('experiment_name')['avg_latency_ms'].mean().idxmin()
        fastest_latency = real_perf_df.groupby('experiment_name')['avg_latency_ms'].mean().min()
        print(f"  🚀 Fastest experiment: {fastest_exp} ({fastest_latency:.2f}ms avg latency)")
    
    if 'peak_ram_mb' in real_perf_df.columns:
        most_efficient_exp = real_perf_df.groupby('experiment_name')['peak_ram_mb'].mean().idxmin()
        least_memory = real_perf_df.groupby('experiment_name')['peak_ram_mb'].mean().min()
        print(f"  🧠 Most memory efficient: {most_efficient_exp} ({least_memory:.0f}MB peak RAM)")

# Recommendations for paper
print("\n💡 RECOMMENDATIONS FOR YOUR PAPER:")
print("  1. 📊 Use the accuracy summary tables to compare model performance")
print("  2. ⚡ Include efficiency metrics to show computational requirements")
print("  3. 🔄 Combine accuracy and efficiency for trade-off analysis")
print("  4. 📱 Use edge deployment analysis for practical deployment insights")
print("  5. 📈 Show statistical significance of denoising effects (if applicable)")

print("\n📁 GENERATED FILES:")
print("  • Summary tables (CSV format for analysis)")
print("  • LaTeX tables (ready for paper)")
print("  • Visualization plots (for figures)")
print("  • This comprehensive analysis notebook")

print("\n🎉 ANALYSIS COMPLETE!")
print("Your experiment data contains rich efficiency information that can")
print("significantly strengthen your research paper with quantitative")
print("performance metrics and practical deployment insights.")
# Out:
# 🎯 KEY FINDINGS AND RECOMMENDATIONS
# ============================================================
#
# 📊 DATA AVAILABILITY:
#   ✅ Accuracy data: 185 records
#   ⚡ Efficiency data: 433 records
#   🔄 Combined data: 325 records
#
# 🔍 ACCURACY INSIGHTS:
#   🏆 Best performing experiment: chronos_trained_inference_ohiot1dm_denoised (RMSE: 30.6543)
#
# ⚡ EFFICIENCY INSIGHTS:
#   🚀 Fastest experiment: chronos_trained_inference_ohiot1dm_noisy (11352.04ms avg latency)
#   🧠 Most memory efficient: chronos_trained_inference_ohiot1dm_denoised (1622MB peak RAM)
#
# 💡 RECOMMENDATIONS FOR YOUR PAPER:
#   1. 📊 Use the accuracy summary tables to compare model performance
#   2. ⚡ Include efficiency metrics to show computational requirements
#   3. 🔄 Combine accuracy and efficiency for trade-off analysis
#   4. 📱 Use edge deployment analysis for practical deployment insights
#   5. 📈 Show statistical significance of denoising effects (if applicable)
#
# 📁 GENERATED FILES:
#   • Summary tables (CSV format for analysis)
#   • LaTeX tables (ready for paper)
#   • Visualization plots (for figures)
#   • This comprehensive analysis notebook
#
# 🎉 ANALYSIS COMPLETE!
# Your experiment data contains rich efficiency information that can
# significantly strengthen your research paper with quantitative
# performance metrics and practical deployment insights.
