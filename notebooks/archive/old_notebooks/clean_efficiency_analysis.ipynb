# %% [markdown]
# # 🔄 Notebook Moved
#
# ## This notebook has been consolidated into the Ultimate LLM Efficiency Analysis
#
# **Please use:** `ultimate_llm_efficiency_analysis.ipynb`
#
# The new notebook includes:
# - ✅ All inference analysis features
# - ✅ Training efficiency analysis
# - ✅ Distillation performance analysis
# - ✅ Edge deployment assessment
# - ✅ Energy and sustainability metrics
# - ✅ Comprehensive reporting
# - ✅ Organized outputs to `/outputs` folder
#
# **Location:** `/notebooks/ultimate_llm_efficiency_analysis.ipynb`

# %%
# This notebook has been moved
print("🔄 Please use: ultimate_llm_efficiency_analysis.ipynb")
print("📍 Location: /notebooks/ultimate_llm_efficiency_analysis.ipynb")
print("✨ New features: Training analysis, Distillation analysis, Complete reporting")
